# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

print(api_key is not None)
# Out:
# True

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

chat = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.1,)

# %%
haiku_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a haiku expert. especially good at writing haiku about programming languages. Write a haiku about the following language."),
    ("human", "Write a haiku about {language}"),
])

haiku_chain = haiku_prompt | chat

# %%
explanation_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a literature expert who explains haiku in a clear and simple way."),
    ("human", """
Here is a haiku:

{haiku}

First, show the original haiku.
Then, explain the meaning of the haiku in a clear and simple way.
"""),
])

explanation_chain = explanation_prompt | chat

# %%
result = final_chain.invoke({"language": "Python"})

print(result.content)
# Out:
# Original haiku:
# Indentation rules,
# Clean syntax and readability,
# Pythonic beauty.
#
# Explanation:
# This haiku praises the beauty of writing code in Python. It highlights the importance of following indentation rules, maintaining clean syntax, and ensuring readability in Python programming. The poet finds beauty in the structured and elegant nature of Python code, appreciating its simplicity and efficiency.
